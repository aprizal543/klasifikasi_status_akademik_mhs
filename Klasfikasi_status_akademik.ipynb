# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Memuat dataset dan menampilkan
df = pd.read_excel('Dataset_Mahasiswa_Kehadiran_Aktivitas_IPK.xlsx')
df
# Out:
#               Nama Jenis Kelamin  Umur Status Menikah  Kehadiran (%)  \
# 0      Kiki Ananda     Laki-laki    20  Belum Menikah             73
# 1      Putri Fauzi     Laki-laki    21  Belum Menikah             42
# 2     Mira Hidayat     Laki-laki    25  Belum Menikah             71
# 3      Mira Ananda     Laki-laki    23  Belum Menikah             44
# 4    Mira Septiani     Laki-laki    21        Menikah             54
# ..             ...           ...   ...            ...            ...
# 495   Putri Ananda     Perempuan    20        Menikah             98
# 496   Umi Ramadhan     Perempuan    23  Belum Menikah             77
# 497   Sari Pratama     Perempuan    19  Belum Menikah             41
# 498     Dina Putri     Perempuan    24  Belum Menikah             45
# 499  Gina Septiani     Perempuan    23  Belum Menikah             59
#
#      Partisipasi Diskusi (skor)  Nilai Tugas (rata-rata)  \
# 0                            99                       91
# ...

# %%
# Melihat informasi dari datset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nama                         500 non-null    object
#  1   Jenis Kelamin                500 non-null    object
#  2   Umur                         500 non-null    int64
#  3   Status Menikah               500 non-null    object
#  4   Kehadiran (%)                500 non-null    int64
#  5   Partisipasi Diskusi (skor)   500 non-null    int64
#  6   Nilai Tugas (rata-rata)      500 non-null    int64
#  7   Aktivitas E-Learning (skor)  500 non-null    int64
#  8   IPK                          500 non-null    float64
#  9   Status Akademik              500 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 39.2+ KB

# %%
# Anayalisis deskriptif
df.describe()
# Out:
#              Umur  Kehadiran (%)  Partisipasi Diskusi (skor)  \
# count  500.000000     500.000000                  500.000000
# mean    21.540000      69.430000                   69.618000
# std      2.267749      17.891263                   17.342017
# min     18.000000      40.000000                   40.000000
# 25%     20.000000      54.000000                   55.000000
# 50%     22.000000      69.000000                   69.500000
# 75%     23.000000      85.000000                   84.000000
# max     25.000000     100.000000                  100.000000
#
#        Nilai Tugas (rata-rata)  Aktivitas E-Learning (skor)         IPK
# count               500.000000                    500.00000  500.000000
# mean                 70.182000                     69.47600    2.806460
# std                  17.314863                     17.84877    0.723713
# min                  40.000000                     40.00000    1.500000
# ...

# %%
# Cek missing values per fitur
print("\nJumlah missing values per fitur:")
print(df.isnull().sum())
# Out:
# Jumlah missing values per fitur:
# Nama                           0
# Jenis Kelamin                  0
# Umur                           0
# Status Menikah                 0
# Kehadiran (%)                  0
# Partisipasi Diskusi (skor)     0
# Nilai Tugas (rata-rata)        0
# Aktivitas E-Learning (skor)    0
# IPK                            0
# Status Akademik                0
# dtype: int64

# %%
# Ditribusi fitur numerik
num_features = df.select_dtypes(include=[np.number])
plt.figure(figsize=(14, 10))
for i, column in enumerate(num_features.columns, 1):
    plt.subplot(3, 4, i)
    sns.histplot(df[column], bins=30, kde=True, color='purple')
    plt.title(f'Distribusi {column}')
plt.tight_layout()
plt.show()

# %%
# Distribusi fitur kategorikal
cat_features = df.select_dtypes(include=['object'])
plt.figure(figsize=(14, 8))
for i, column in enumerate(cat_features.columns, 1):
    plt.subplot(2, 4, i)
    sns.countplot(y=df[column], palette='viridis')
    plt.title(f'Distribusi {column}')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-16-145008007.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[column], palette='viridis')
# /tmp/ipython-input-16-145008007.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[column], palette='viridis')
# /tmp/ipython-input-16-145008007.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df[column], palette='viridis')
# /tmp/ipython-input-16-145008007.py:6: FutureWarning:
#
# ...

# %%
# Cek outlier pada dataset
num_features = df.select_dtypes(include=[np.number])

plt.figure(figsize=(14, 10))
for i, column in enumerate(num_features.columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(x=df[column], color='skyblue')

plt.tight_layout()
plt.show()

# %%
# Heatmap korelasi untuk fitur numerik
plt.figure(figsize=(12, 10))
correlation_matrix = num_features.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap Korelasi Fitur Numerik')
plt.show()

# %%
# Menghapus fitur 'Nama' dari dataset
df = df.drop('Nama', axis=1)
df
# Out:
#     Jenis Kelamin  Umur Status Menikah  Kehadiran (%)  \
# 0       Laki-laki    20  Belum Menikah             73
# 1       Laki-laki    21  Belum Menikah             42
# 2       Laki-laki    25  Belum Menikah             71
# 3       Laki-laki    23  Belum Menikah             44
# 4       Laki-laki    21        Menikah             54
# ..            ...   ...            ...            ...
# 495     Perempuan    20        Menikah             98
# 496     Perempuan    23  Belum Menikah             77
# 497     Perempuan    19  Belum Menikah             41
# 498     Perempuan    24  Belum Menikah             45
# 499     Perempuan    23  Belum Menikah             59
#
#      Partisipasi Diskusi (skor)  Nilai Tugas (rata-rata)  \
# 0                            99                       91
# 1                            83                       53
# 2                            61                       87
# 3                            88                       62
# ...

# %%
# Visualisasi distribusi variabel target
plt.figure(figsize=(8, 4))
sns.countplot(x='Status Akademik', data=df, palette='viridis')
plt.title('Distribusi Variabel Target (Status Akademik)')
plt.show()
# Out:
# /tmp/ipython-input-19-480246031.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Status Akademik', data=df, palette='viridis')
